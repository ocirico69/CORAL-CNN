# %%
import sys
sys.path.append("/content/drive/MyDrive/Acne LDL/code")

# %%
# library
# standard library
import os, sys

# third-party library
import numpy as np
import collections
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader
from dataset import dataset_processing
from timeit import default_timer as timer
from utils.report import report_precision_se_sp_yi, report_mae_mse
from utils.utils import Logger, AverageMeter, time_to_str, weights_init
from utils.genLD import genLD
from model.resnet50 import resnet50
import torch.backends.cudnn as cudnn
from transforms.affine_transforms import *
import time
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import os
import time
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from timeit import default_timer as timer
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_score,
    recall_score,
    f1_score
)

# ============================================================
# LOGGER
# ============================================================
LOG_FILE_NAME = '/content/drive/MyDrive/Acne LDL/code/log_' + time.strftime(
    "%Y-%m-%d_%H-%M-%S", time.localtime()) + '.log'

log = Logger()
log.open(LOG_FILE_NAME, mode="a")

BATCH_SIZE = 32
BATCH_SIZE_TEST = 20
LR = 0.001              # learning rate
NUM_WORKERS = 12
NUM_CLASSES = 4
lr_steps = [30, 60, 90, 120]

# ============================================================
# DEVICE
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# SAVE PATH
# ============================================================
SAVE_MODEL_TPL = "/content/drive/MyDrive/Acne LDL/code/LDL_Fold{idx}.pth"
CM_PNG_TPL     = "/content/drive/MyDrive/Acne LDL/code/LDL_Fold{idx}_confusion.png"

# ============================================================
# TRAIN / VAL / TEST
# ============================================================
def trainval_test(cross_val_index, sigma, lam):

    TRAIN_FILE = f"/content/drive/MyDrive/Acne LDL/code/Classification/NNEW_trainval_{cross_val_index}.txt"
    TEST_FILE  = f"/content/drive/MyDrive/Acne LDL/code/Classification/NNEW_test_{cross_val_index}.txt"
    DATA_PATH  = "/content/drive/MyDrive/Acne LDL/code/Classification/JPEGImages"

    normalize = transforms.Normalize(
        mean=[0.45815152, 0.361242, 0.29348266],
        std=[0.2814769, 0.226306, 0.20132513]
    )

    dset_train = dataset_processing.DatasetProcessing(
        DATA_PATH, TRAIN_FILE,
        transform=transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.RandomCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            RandomRotate(rotation_range=20),
            normalize,
        ])
    )

    dset_test = dataset_processing.DatasetProcessing(
        DATA_PATH, TEST_FILE,
        transform=transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            normalize,
        ])
    )

    train_loader = DataLoader(
        dset_train,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=False
    )

    test_loader = DataLoader(
        dset_test,
        batch_size=BATCH_SIZE_TEST,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=False
    )

    cnn = resnet50().to(device)

    params = [{'params': v, 'lr': LR, 'weight_decay': 5e-4}
              for _, v in cnn.named_parameters() if v.requires_grad]

    optimizer = torch.optim.SGD(params, momentum=0.9)

    loss_func = nn.CrossEntropyLoss().to(device)
    kl_loss_1 = nn.KLDivLoss().to(device)
    kl_loss_2 = nn.KLDivLoss().to(device)
    kl_loss_3 = nn.KLDivLoss().to(device)

    history = {
        "test_acc": [],
        "mae": [],
        "mse": []
    }

    start = timer()

    # ========================================================
    # TRAINING LOOP
    # ========================================================
    for epoch in range(lr_steps[-1]):

        cnn.train()
        losses = AverageMeter()

        for b_x, b_y, b_l in train_loader:

            b_x = b_x.to(device)
            b_l = b_l.numpy() - 1

            ld = genLD(b_l, sigma, 'klloss', 65)
            ld_4 = np.vstack((
                np.sum(ld[:, :5], 1),
                np.sum(ld[:, 5:20], 1),
                np.sum(ld[:, 20:50], 1),
                np.sum(ld[:, 50:], 1)
            )).transpose()

            ld = torch.from_numpy(ld).float().to(device)
            ld_4 = torch.from_numpy(ld_4).float().to(device)

            cls, cou, cou2cls = cnn(b_x, None)

            loss_cls = kl_loss_1(torch.log(cls), ld_4) * 4.0
            loss_cou = kl_loss_2(torch.log(cou), ld) * 65.0
            loss_cls_cou = kl_loss_3(torch.log(cou2cls), ld_4) * 4.0

            loss = (loss_cls + loss_cls_cou) * 0.5 * lam + loss_cou * (1.0 - lam)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            losses.update(loss.item(), b_x.size(0))

        # ====================================================
        # VALIDATION (START EPOCH >= 9)
        # ====================================================
        if epoch >= 9:
            cnn.eval()

            y_true, y_pred = [], []
            l_true, l_pred = [], []

            with torch.no_grad():
                for x, y, l in test_loader:
                    x = x.to(device)
                    y = y.to(device)

                    cls, cou, cou2cls = cnn(x, None)
                    _, preds = torch.max(cls + cou2cls, 1)

                    y_true.extend(y.cpu().numpy())
                    y_pred.extend(preds.cpu().numpy())

                    _, preds_l = torch.max(cou, 1)
                    preds_l = (preds_l + 1).cpu().numpy()
                    l_true.extend(l.numpy())
                    l_pred.extend(preds_l)

            y_true = np.array(y_true)
            y_pred = np.array(y_pred)
            l_true = np.array(l_true)
            l_pred = np.array(l_pred)

            acc = 100.0 * (y_true == y_pred).mean()
            prec = 100.0 * precision_score(y_true, y_pred, average="macro", zero_division=0)
            rec  = 100.0 * recall_score(y_true, y_pred, average="macro", zero_division=0)
            f1   = 100.0 * f1_score(y_true, y_pred, average="macro", zero_division=0)

            _, MAE, MSE, _ = report_mae_mse(l_true, l_pred, y_true)

            history["test_acc"].append(acc)
            history["mae"].append(MAE)
            history["mse"].append(MSE)

            # ================= CORAL-STYLE PRINT =================
            print(f"Fold {cross_val_index} - Epoch {epoch+1}/{lr_steps[-1]}")
            print("------------------------------------------------------------")
            print(f"Train Loss: {losses.avg:.4f}")
            print(f"Val Acc:   {acc:.2f}%\n")

    # ========================================================
    # CONFUSION MATRIX (PER FOLD)
    # ========================================================
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure(figsize=(5, 4))
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.title(f"Confusion Matrix Fold {cross_val_index}")
    plt.savefig(CM_PNG_TPL.format(idx=cross_val_index))
    plt.close()

    # ========================================================
    # SAVE MODEL (PER FOLD)
    # ========================================================
    torch.save(cnn.state_dict(), SAVE_MODEL_TPL.format(idx=cross_val_index))

    # ========================================================
    # FINAL PRINT (CORAL STYLE)
    # ========================================================
    print(f"\nTest Set Evaluation Results (Fold {cross_val_index}):")
    print(f"  • Accuracy:  {acc:.2f}%")
    print(f"  • Precision: {prec:.2f}%")
    print(f"  • Recall:    {rec:.2f}%")
    print(f"  • F1-Score:  {f1:.2f}%")
    print(f"  • MAE:       {MAE:.3f}")
    print(f"  • MSE:       {MSE:.3f}\n")

    print(f"Fold {cross_val_index} Summary:")
    print(f"  • Test Accuracy: {acc:.2f}%")
    print(f"  • Test F1-Score: {f1:.2f}%\n")

    return acc, prec, rec, f1, MAE, MSE


# ============================================================
# MAIN (5-FOLD CV)
# ============================================================
cross_val_lists = ['0', '1', '2', '3', '4']
results = []

for fold in cross_val_lists:
    log.write('\n\ncross_val_index: ' + fold + '\n\n')
    results.append(trainval_test(fold, sigma=3.0, lam=0.6))

results = np.array(results)

# ============================================================
# K-FOLD SUMMARY (CORAL STYLE)
# ============================================================
print("\n============================================================")
print("K-FOLD TEST SET EVALUATION RESULTS")
print("============================================================\n")

print(" fold  acc     prec    recall  f1     mae     mse")
for i, r in enumerate(results):
    print(f"{i+1:5d}  {r[0]:6.2f}  {r[1]:6.2f}  {r[2]:6.2f}  {r[3]:6.2f}  {r[4]:6.3f}  {r[5]:6.3f}")

print("\n============================================================")
print("SUMMARY STATISTICS")
print("============================================================\n")

print("📈 Final Test Set Performance :")
print(f"  • Mean Accuracy:  {results[:,0].mean():.2f}% ± {results[:,0].std():.2f}%")
print(f"  • Mean Precision: {results[:,1].mean():.2f}% ± {results[:,1].std():.2f}%")
print(f"  • Mean Recall:    {results[:,2].mean():.2f}% ± {results[:,2].std():.2f}%")
print(f"  • Mean F1-Score:  {results[:,3].mean():.2f}% ± {results[:,3].std():.2f}%")
print(f"  • Mean MAE:       {results[:,4].mean():.3f}")
print(f"  • Mean MSE:       {results[:,5].mean():.3f}")
# Out:
# Device: cuda
#
#
# cross_val_index: 0
#
# Fold 0 - Epoch 10/120
# ------------------------------------------------------------
# Train Loss: 0.3425
# Val Acc:   75.00%
#
# Fold 0 - Epoch 11/120
# ------------------------------------------------------------
# Train Loss: 0.3657
# Val Acc:   75.68%
#
# Fold 0 - Epoch 12/120
# ------------------------------------------------------------
# Train Loss: 0.3024
# Val Acc:   79.79%
#
# Fold 0 - Epoch 13/120
# ------------------------------------------------------------
# Train Loss: 0.2702
# Val Acc:   78.08%
#
# Fold 0 - Epoch 14/120
# ------------------------------------------------------------
# Train Loss: 0.2812
# Val Acc:   73.29%
#
# Fold 0 - Epoch 15/120
# ------------------------------------------------------------
# Train Loss: 0.2830
# Val Acc:   81.16%
#
# Fold 0 - Epoch 16/120
# ------------------------------------------------------------
# Train Loss: 0.2408
# Val Acc:   79.79%
#
# Fold 0 - Epoch 17/120
# ------------------------------------------------------------
# Train Loss: 0.2722
# Val Acc:   78.42%
#
# Fold 0 - Epoch 18/120
# ------------------------------------------------------------
# Train Loss: 0.2528
# Val Acc:   81.85%
#
# Fold 0 - Epoch 19/120
# ------------------------------------------------------------
# Train Loss: 0.2599
# Val Acc:   80.48%
#
# Fold 0 - Epoch 20/120
# ------------------------------------------------------------
# Train Loss: 0.2463
# Val Acc:   74.66%
#
# Fold 0 - Epoch 21/120
# ------------------------------------------------------------
# Train Loss: 0.2696
# Val Acc:   72.60%
#
# Fold 0 - Epoch 22/120
# ------------------------------------------------------------
# Train Loss: 0.2208
# Val Acc:   75.68%
#
# Fold 0 - Epoch 23/120
# ------------------------------------------------------------
# Train Loss: 0.2077
# Val Acc:   77.05%
#
# Fold 0 - Epoch 24/120
# ------------------------------------------------------------
# Train Loss: 0.2229
# Val Acc:   71.58%
#
# Fold 0 - Epoch 25/120
# ------------------------------------------------------------
# Train Loss: 0.2217
# Val Acc:   82.19%
#
# Fold 0 - Epoch 26/120
# ------------------------------------------------------------
# Train Loss: 0.2066
# Val Acc:   80.48%
#
# Fold 0 - Epoch 27/120
# ------------------------------------------------------------
# Train Loss: 0.1752
# Val Acc:   82.53%
#
# Fold 0 - Epoch 28/120
# ------------------------------------------------------------
# Train Loss: 0.1888
# Val Acc:   74.32%
#
# Fold 0 - Epoch 29/120
# ------------------------------------------------------------
# Train Loss: 0.1872
# Val Acc:   74.32%
#
# Fold 0 - Epoch 30/120
# ------------------------------------------------------------
# Train Loss: 0.1927
# Val Acc:   68.84%
#
# Fold 0 - Epoch 31/120
# ------------------------------------------------------------
# Train Loss: 0.2423
# Val Acc:   81.51%
#
# Fold 0 - Epoch 32/120
# ------------------------------------------------------------
# Train Loss: 0.1735
# Val Acc:   75.34%
#
# Fold 0 - Epoch 33/120
# ------------------------------------------------------------
# Train Loss: 0.1828
# Val Acc:   75.34%
#
# Fold 0 - Epoch 34/120
# ------------------------------------------------------------
# Train Loss: 0.1556
# Val Acc:   77.74%
#
# Fold 0 - Epoch 35/120
# ------------------------------------------------------------
# Train Loss: 0.1566
# Val Acc:   71.58%
#
# Fold 0 - Epoch 36/120
# ------------------------------------------------------------
# Train Loss: 0.1825
# Val Acc:   77.74%
#
# Fold 0 - Epoch 37/120
# ------------------------------------------------------------
# Train Loss: 0.1446
# Val Acc:   81.16%
#
# Fold 0 - Epoch 38/120
# ------------------------------------------------------------
# Train Loss: 0.1441
# Val Acc:   81.51%
#
# Fold 0 - Epoch 39/120
# ------------------------------------------------------------
# Train Loss: 0.1512
# Val Acc:   81.16%
#
# Fold 0 - Epoch 40/120
# ------------------------------------------------------------
# Train Loss: 0.1536
# Val Acc:   72.95%
#
# Fold 0 - Epoch 41/120
# ------------------------------------------------------------
# Train Loss: 0.1309
# Val Acc:   81.85%
#
# Fold 0 - Epoch 42/120
# ------------------------------------------------------------
# Train Loss: 0.1192
# Val Acc:   80.14%
#
# Fold 0 - Epoch 43/120
# ------------------------------------------------------------
# Train Loss: 0.1155
# Val Acc:   77.05%
#
# Fold 0 - Epoch 44/120
# ------------------------------------------------------------
# Train Loss: 0.1302
# Val Acc:   80.14%
#
# Fold 0 - Epoch 45/120
# ------------------------------------------------------------
# Train Loss: 0.1346
# Val Acc:   76.37%
#
# Fold 0 - Epoch 46/120
# ------------------------------------------------------------
# Train Loss: 0.1460
# Val Acc:   79.79%
#
# Fold 0 - Epoch 47/120
# ------------------------------------------------------------
# Train Loss: 0.1067
# Val Acc:   80.48%
#
# Fold 0 - Epoch 48/120
# ------------------------------------------------------------
# Train Loss: 0.1032
# Val Acc:   80.14%
#
# Fold 0 - Epoch 49/120
# ------------------------------------------------------------
# Train Loss: 0.1088
# Val Acc:   81.16%
#
# Fold 0 - Epoch 50/120
# ------------------------------------------------------------
# Train Loss: 0.0999
# Val Acc:   79.11%
#
# Fold 0 - Epoch 51/120
# ------------------------------------------------------------
# Train Loss: 0.1033
# Val Acc:   82.88%
#
# Fold 0 - Epoch 52/120
# ------------------------------------------------------------
# Train Loss: 0.0999
# Val Acc:   79.79%
#
# Fold 0 - Epoch 53/120
# ------------------------------------------------------------
# Train Loss: 0.1049
# Val Acc:   81.16%
#
# Fold 0 - Epoch 54/120
# ------------------------------------------------------------
# Train Loss: 0.1056
# Val Acc:   81.85%
#
# Fold 0 - Epoch 55/120
# ------------------------------------------------------------
# Train Loss: 0.1015
# Val Acc:   75.00%
#
# Fold 0 - Epoch 56/120
# ------------------------------------------------------------
# Train Loss: 0.0972
# Val Acc:   85.27%
#
# Fold 0 - Epoch 57/120
# ------------------------------------------------------------
# Train Loss: 0.0954
# Val Acc:   81.16%
#
# Fold 0 - Epoch 58/120
# ------------------------------------------------------------
# Train Loss: 0.0892
# Val Acc:   80.82%
#
# Fold 0 - Epoch 59/120
# ------------------------------------------------------------
# Train Loss: 0.0911
# Val Acc:   79.45%
#
# Fold 0 - Epoch 60/120
# ------------------------------------------------------------
# Train Loss: 0.1082
# Val Acc:   83.90%
#
# Fold 0 - Epoch 61/120
# ------------------------------------------------------------
# Train Loss: 0.0866
# Val Acc:   77.40%
#
# Fold 0 - Epoch 62/120
# ------------------------------------------------------------
# Train Loss: 0.0946
# Val Acc:   81.85%
#
# Fold 0 - Epoch 63/120
# ------------------------------------------------------------
# Train Loss: 0.0845
# Val Acc:   81.85%
#
# Fold 0 - Epoch 64/120
# ------------------------------------------------------------
# Train Loss: 0.0708
# Val Acc:   76.71%
#
# Fold 0 - Epoch 65/120
# ------------------------------------------------------------
# Train Loss: 0.0669
# Val Acc:   79.79%
#
# Fold 0 - Epoch 66/120
# ------------------------------------------------------------
# Train Loss: 0.0651
# Val Acc:   79.79%
#
# Fold 0 - Epoch 67/120
# ------------------------------------------------------------
# Train Loss: 0.0695
# Val Acc:   79.11%
#
# Fold 0 - Epoch 68/120
# ------------------------------------------------------------
# Train Loss: 0.0661
# Val Acc:   80.48%
#
# Fold 0 - Epoch 69/120
# ------------------------------------------------------------
# Train Loss: 0.0692
# Val Acc:   78.77%
#
# Fold 0 - Epoch 70/120
# ------------------------------------------------------------
# Train Loss: 0.0740
# Val Acc:   82.53%
#
# Fold 0 - Epoch 71/120
# ------------------------------------------------------------
# Train Loss: 0.0811
# Val Acc:   81.16%
#
# Fold 0 - Epoch 72/120
# ------------------------------------------------------------
# Train Loss: 0.0675
# Val Acc:   80.48%
#
# Fold 0 - Epoch 73/120
# ------------------------------------------------------------
# Train Loss: 0.0636
# Val Acc:   80.82%
#
# Fold 0 - Epoch 74/120
# ------------------------------------------------------------
# Train Loss: 0.0544
# Val Acc:   78.08%
#
# Fold 0 - Epoch 75/120
# ------------------------------------------------------------
# Train Loss: 0.0544
# Val Acc:   80.82%
#
# Fold 0 - Epoch 76/120
# ------------------------------------------------------------
# Train Loss: 0.0525
# Val Acc:   80.48%
#
# Fold 0 - Epoch 77/120
# ------------------------------------------------------------
# Train Loss: 0.0605
# Val Acc:   81.51%
#
# Fold 0 - Epoch 78/120
# ------------------------------------------------------------
# Train Loss: 0.0608
# Val Acc:   80.14%
#
# Fold 0 - Epoch 79/120
# ------------------------------------------------------------
# Train Loss: 0.0600
# Val Acc:   80.14%
#
# Fold 0 - Epoch 80/120
# ------------------------------------------------------------
# Train Loss: 0.0587
# Val Acc:   79.79%
#
# Fold 0 - Epoch 81/120
# ------------------------------------------------------------
# Train Loss: 0.0575
# Val Acc:   82.19%
#
# Fold 0 - Epoch 82/120
# ------------------------------------------------------------
# Train Loss: 0.0477
# Val Acc:   80.48%
#
# Fold 0 - Epoch 83/120
# ------------------------------------------------------------
# Train Loss: 0.0495
# Val Acc:   79.45%
#
# Fold 0 - Epoch 84/120
# ------------------------------------------------------------
# Train Loss: 0.0521
# Val Acc:   79.11%
#
# Fold 0 - Epoch 85/120
# ------------------------------------------------------------
# Train Loss: 0.0522
# Val Acc:   78.42%
#
# Fold 0 - Epoch 86/120
# ------------------------------------------------------------
# Train Loss: 0.0469
# Val Acc:   80.48%
#
# Fold 0 - Epoch 87/120
# ------------------------------------------------------------
# Train Loss: 0.0583
# Val Acc:   79.79%
#
# Fold 0 - Epoch 88/120
# ------------------------------------------------------------
# Train Loss: 0.0444
# Val Acc:   81.51%
#
# Fold 0 - Epoch 89/120
# ------------------------------------------------------------
# Train Loss: 0.0437
# Val Acc:   81.16%
#
# Fold 0 - Epoch 90/120
# ------------------------------------------------------------
# Train Loss: 0.0401
# Val Acc:   79.79%
#
# Fold 0 - Epoch 91/120
# ------------------------------------------------------------
# Train Loss: 0.0405
# Val Acc:   80.48%
#
# Fold 0 - Epoch 92/120
# ------------------------------------------------------------
# Train Loss: 0.0538
# Val Acc:   80.82%
#
# Fold 0 - Epoch 93/120
# ------------------------------------------------------------
# Train Loss: 0.0522
# Val Acc:   81.51%
#
# Fold 0 - Epoch 94/120
# ------------------------------------------------------------
# Train Loss: 0.0452
# Val Acc:   79.79%
#
# Fold 0 - Epoch 95/120
# ------------------------------------------------------------
# Train Loss: 0.0426
# Val Acc:   80.82%
#
# Fold 0 - Epoch 96/120
# ------------------------------------------------------------
# Train Loss: 0.0488
# Val Acc:   82.19%
#
# Fold 0 - Epoch 97/120
# ------------------------------------------------------------
# Train Loss: 0.0434
# Val Acc:   79.79%
#
# Fold 0 - Epoch 98/120
# ------------------------------------------------------------
# Train Loss: 0.0432
# Val Acc:   80.14%
#
# Fold 0 - Epoch 99/120
# ------------------------------------------------------------
# Train Loss: 0.0390
# Val Acc:   81.51%
#
# Fold 0 - Epoch 100/120
# ------------------------------------------------------------
# Train Loss: 0.0415
# Val Acc:   78.08%
#
# Fold 0 - Epoch 101/120
# ------------------------------------------------------------
# Train Loss: 0.0373
# Val Acc:   78.42%
#
# Fold 0 - Epoch 102/120
# ------------------------------------------------------------
# Train Loss: 0.0388
# Val Acc:   81.16%
#
# Fold 0 - Epoch 103/120
# ------------------------------------------------------------
# Train Loss: 0.0359
# Val Acc:   81.16%
#
# Fold 0 - Epoch 104/120
# ------------------------------------------------------------
# Train Loss: 0.0343
# Val Acc:   80.48%
#
# Fold 0 - Epoch 105/120
# ------------------------------------------------------------
# Train Loss: 0.0380
# Val Acc:   79.79%
#
# Fold 0 - Epoch 106/120
# ------------------------------------------------------------
# Train Loss: 0.0431
# Val Acc:   76.03%
#
# Fold 0 - Epoch 107/120
# ------------------------------------------------------------
# Train Loss: 0.1760
# Val Acc:   72.95%
#
# Fold 0 - Epoch 108/120
# ------------------------------------------------------------
# Train Loss: 0.1017
# Val Acc:   78.77%
#
# Fold 0 - Epoch 109/120
# ------------------------------------------------------------
# Train Loss: 0.0473
# Val Acc:   79.79%
#
# Fold 0 - Epoch 110/120
# ------------------------------------------------------------
# Train Loss: 0.0371
# Val Acc:   79.79%
#
# Fold 0 - Epoch 111/120
# ------------------------------------------------------------
# Train Loss: 0.0381
# Val Acc:   81.16%
#
# Fold 0 - Epoch 112/120
# ------------------------------------------------------------
# Train Loss: 0.0376
# Val Acc:   78.08%
#
# Fold 0 - Epoch 113/120
# ------------------------------------------------------------
# Train Loss: 0.0305
# Val Acc:   82.88%
#
# Fold 0 - Epoch 114/120
# ------------------------------------------------------------
# Train Loss: 0.0276
# Val Acc:   79.45%
#
# Fold 0 - Epoch 115/120
# ------------------------------------------------------------
# Train Loss: 0.0342
# Val Acc:   82.53%
#
# Fold 0 - Epoch 116/120
# ------------------------------------------------------------
# Train Loss: 0.0379
# Val Acc:   78.77%
#
# Fold 0 - Epoch 117/120
# ------------------------------------------------------------
# Train Loss: 0.0341
# Val Acc:   81.85%
#
# Fold 0 - Epoch 118/120
# ------------------------------------------------------------
# Train Loss: 0.0391
# Val Acc:   80.82%
#
# Fold 0 - Epoch 119/120
# ------------------------------------------------------------
# Train Loss: 0.0337
# Val Acc:   80.82%
#
# Fold 0 - Epoch 120/120
# ------------------------------------------------------------
# Train Loss: 0.0331
# Val Acc:   81.85%
#
#
# Test Set Evaluation Results (Fold 0):
#   • Accuracy:  81.85%
#   • Precision: 82.22%
#   • Recall:    79.22%
#   • F1-Score:  80.41%
#   • MAE:       3.188
#   • MSE:       6.060
#
# Fold 0 Summary:
#   • Test Accuracy: 81.85%
#   • Test F1-Score: 80.41%
#
#
#
# cross_val_index: 1
#
# Fold 1 - Epoch 10/120
# ------------------------------------------------------------
# Train Loss: 0.3439
# Val Acc:   74.66%
#
# Fold 1 - Epoch 11/120
# ------------------------------------------------------------
# Train Loss: 0.3049
# Val Acc:   77.40%
#
# Fold 1 - Epoch 12/120
# ------------------------------------------------------------
# Train Loss: 0.3346
# Val Acc:   77.40%
#
# Fold 1 - Epoch 13/120
# ------------------------------------------------------------
# Train Loss: 0.3140
# Val Acc:   72.60%
#
# Fold 1 - Epoch 14/120
# ------------------------------------------------------------
# Train Loss: 0.2982
# Val Acc:   69.52%
#
# Fold 1 - Epoch 15/120
# ------------------------------------------------------------
# Train Loss: 0.3405
# Val Acc:   77.74%
#
# Fold 1 - Epoch 16/120
# ------------------------------------------------------------
# Train Loss: 0.2871
# Val Acc:   74.66%
#
# Fold 1 - Epoch 17/120
# ------------------------------------------------------------
# Train Loss: 0.2383
# Val Acc:   79.11%
#
# Fold 1 - Epoch 18/120
# ------------------------------------------------------------
# Train Loss: 0.2899
# Val Acc:   66.44%
#
# Fold 1 - Epoch 19/120
# ------------------------------------------------------------
# Train Loss: 0.3141
# Val Acc:   76.71%
#
# Fold 1 - Epoch 20/120
# ------------------------------------------------------------
# Train Loss: 0.2711
# Val Acc:   82.53%
#
# Fold 1 - Epoch 21/120
# ------------------------------------------------------------
# Train Loss: 0.2609
# Val Acc:   79.79%
#
# Fold 1 - Epoch 22/120
# ------------------------------------------------------------
# Train Loss: 0.2176
# Val Acc:   76.37%
#
# Fold 1 - Epoch 23/120
# ------------------------------------------------------------
# Train Loss: 0.2857
# Val Acc:   84.93%
#
# Fold 1 - Epoch 24/120
# ------------------------------------------------------------
# Train Loss: 0.2187
# Val Acc:   83.56%
#
# Fold 1 - Epoch 25/120
# ------------------------------------------------------------
# Train Loss: 0.2216
# Val Acc:   81.51%
#
# Fold 1 - Epoch 26/120
# ------------------------------------------------------------
# Train Loss: 0.1769
# Val Acc:   82.19%
#
# Fold 1 - Epoch 27/120
# ------------------------------------------------------------
# Train Loss: 0.1946
# Val Acc:   71.58%
#
# Fold 1 - Epoch 28/120
# ------------------------------------------------------------
# Train Loss: 0.2272
# Val Acc:   82.19%
#
# Fold 1 - Epoch 29/120
# ------------------------------------------------------------
# Train Loss: 0.1879
# Val Acc:   76.03%
#
# Fold 1 - Epoch 30/120
# ------------------------------------------------------------
# Train Loss: 0.1977
# Val Acc:   81.85%
#
# Fold 1 - Epoch 31/120
# ------------------------------------------------------------
# Train Loss: 0.1971
# Val Acc:   81.85%
#
# Fold 1 - Epoch 32/120
# ------------------------------------------------------------
# Train Loss: 0.1672
# Val Acc:   82.53%
#
# Fold 1 - Epoch 33/120
# ------------------------------------------------------------
# Train Loss: 0.1518
# Val Acc:   82.53%
#
# Fold 1 - Epoch 34/120
# ------------------------------------------------------------
# Train Loss: 0.1747
# Val Acc:   82.88%
#
# Fold 1 - Epoch 35/120
# ------------------------------------------------------------
# Train Loss: 0.1370
# Val Acc:   82.53%
#
# Fold 1 - Epoch 36/120
# ------------------------------------------------------------
# Train Loss: 0.1609
# Val Acc:   81.51%
#
# Fold 1 - Epoch 37/120
# ------------------------------------------------------------
# Train Loss: 0.2160
# Val Acc:   78.42%
#
# Fold 1 - Epoch 38/120
# ------------------------------------------------------------
# Train Loss: 0.1543
# Val Acc:   81.85%
#
# Fold 1 - Epoch 39/120
# ------------------------------------------------------------
# Train Loss: 0.1355
# Val Acc:   80.48%
#
# Fold 1 - Epoch 40/120
# ------------------------------------------------------------
# Train Loss: 0.1564
# Val Acc:   80.48%
#
# Fold 1 - Epoch 41/120
# ------------------------------------------------------------
# Train Loss: 0.1384
# Val Acc:   81.16%
#
# Fold 1 - Epoch 42/120
# ------------------------------------------------------------
# Train Loss: 0.1167
# Val Acc:   82.19%
#
# Fold 1 - Epoch 43/120
# ------------------------------------------------------------
# Train Loss: 0.1358
# Val Acc:   78.42%
#
# Fold 1 - Epoch 44/120
# ------------------------------------------------------------
# Train Loss: 0.1372
# Val Acc:   81.51%
#
# Fold 1 - Epoch 45/120
# ------------------------------------------------------------
# Train Loss: 0.1303
# Val Acc:   82.19%
#
# Fold 1 - Epoch 46/120
# ------------------------------------------------------------
# Train Loss: 0.1315
# Val Acc:   81.16%
#
# Fold 1 - Epoch 47/120
# ------------------------------------------------------------
# Train Loss: 0.1388
# Val Acc:   78.77%
#
# Fold 1 - Epoch 48/120
# ------------------------------------------------------------
# Train Loss: 0.1521
# Val Acc:   76.03%
#
# Fold 1 - Epoch 49/120
# ------------------------------------------------------------
# Train Loss: 0.1201
# Val Acc:   84.25%
#
# Fold 1 - Epoch 50/120
# ------------------------------------------------------------
# Train Loss: 0.0990
# Val Acc:   81.51%
#
# Fold 1 - Epoch 51/120
# ------------------------------------------------------------
# Train Loss: 0.1002
# Val Acc:   82.19%
#
# Fold 1 - Epoch 52/120
# ------------------------------------------------------------
# Train Loss: 0.0981
# Val Acc:   81.85%
#
# Fold 1 - Epoch 53/120
# ------------------------------------------------------------
# Train Loss: 0.0927
# Val Acc:   80.48%
#
# Fold 1 - Epoch 54/120
# ------------------------------------------------------------
# Train Loss: 0.1156
# Val Acc:   80.48%
#
# Fold 1 - Epoch 55/120
# ------------------------------------------------------------
# Train Loss: 0.1067
# Val Acc:   81.85%
#
# Fold 1 - Epoch 56/120
# ------------------------------------------------------------
# Train Loss: 0.1097
# Val Acc:   78.42%
#
# Fold 1 - Epoch 57/120
# ------------------------------------------------------------
# Train Loss: 0.2065
# Val Acc:   80.48%
#
# Fold 1 - Epoch 58/120
# ------------------------------------------------------------
# Train Loss: 0.1065
# Val Acc:   82.19%
#
# Fold 1 - Epoch 59/120
# ------------------------------------------------------------
# Train Loss: 0.1062
# Val Acc:   79.79%
#
# Fold 1 - Epoch 60/120
# ------------------------------------------------------------
# Train Loss: 0.0817
# Val Acc:   77.74%
#
# Fold 1 - Epoch 61/120
# ------------------------------------------------------------
# Train Loss: 0.0939
# Val Acc:   81.85%
#
# Fold 1 - Epoch 62/120
# ------------------------------------------------------------
# Train Loss: 0.0765
# Val Acc:   82.19%
#
# Fold 1 - Epoch 63/120
# ------------------------------------------------------------
# Train Loss: 0.0710
# Val Acc:   80.82%
#
# Fold 1 - Epoch 64/120
# ------------------------------------------------------------
# Train Loss: 0.0771
# Val Acc:   79.79%
#
# Fold 1 - Epoch 65/120
# ------------------------------------------------------------
# Train Loss: 0.0798
# Val Acc:   82.19%
#
# Fold 1 - Epoch 66/120
# ------------------------------------------------------------
# Train Loss: 0.0855
# Val Acc:   75.68%
#
# Fold 1 - Epoch 67/120
# ------------------------------------------------------------
# Train Loss: 0.0875
# Val Acc:   82.19%
#
# Fold 1 - Epoch 68/120
# ------------------------------------------------------------
# Train Loss: 0.0798
# Val Acc:   82.19%
#
# Fold 1 - Epoch 69/120
# ------------------------------------------------------------
# Train Loss: 0.0665
# Val Acc:   82.53%
#
# Fold 1 - Epoch 70/120
# ------------------------------------------------------------
# Train Loss: 0.0644
# Val Acc:   80.82%
#
# Fold 1 - Epoch 71/120
# ------------------------------------------------------------
# Train Loss: 0.0632
# Val Acc:   82.19%
#
# Fold 1 - Epoch 72/120
# ------------------------------------------------------------
# Train Loss: 0.0638
# Val Acc:   83.22%
#
# Fold 1 - Epoch 73/120
# ------------------------------------------------------------
# Train Loss: 0.0602
# Val Acc:   81.51%
#
# Fold 1 - Epoch 74/120
# ------------------------------------------------------------
# Train Loss: 0.0643
# Val Acc:   82.19%
#
# Fold 1 - Epoch 75/120
# ------------------------------------------------------------
# Train Loss: 0.0689
# Val Acc:   80.48%
#
# Fold 1 - Epoch 76/120
# ------------------------------------------------------------
# Train Loss: 0.0575
# Val Acc:   82.53%
#
# Fold 1 - Epoch 77/120
# ------------------------------------------------------------
# Train Loss: 0.0547
# Val Acc:   81.16%
#
# Fold 1 - Epoch 78/120
# ------------------------------------------------------------
# Train Loss: 0.0569
# Val Acc:   79.79%
#
# Fold 1 - Epoch 79/120
# ------------------------------------------------------------
# Train Loss: 0.0574
# Val Acc:   82.88%
#
# Fold 1 - Epoch 80/120
# ------------------------------------------------------------
# Train Loss: 0.0494
# Val Acc:   80.82%
#
# Fold 1 - Epoch 81/120
# ------------------------------------------------------------
# Train Loss: 0.0613
# Val Acc:   82.19%
#
# Fold 1 - Epoch 82/120
# ------------------------------------------------------------
# Train Loss: 0.0628
# Val Acc:   82.53%
#
# Fold 1 - Epoch 83/120
# ------------------------------------------------------------
# Train Loss: 0.0560
# Val Acc:   82.19%
#
# Fold 1 - Epoch 84/120
# ------------------------------------------------------------
# Train Loss: 0.0517
# Val Acc:   82.19%
#
# Fold 1 - Epoch 85/120
# ------------------------------------------------------------
# Train Loss: 0.0475
# Val Acc:   82.88%
#
# Fold 1 - Epoch 86/120
# ------------------------------------------------------------
# Train Loss: 0.0468
# Val Acc:   82.88%
#
# Fold 1 - Epoch 87/120
# ------------------------------------------------------------
# Train Loss: 0.0562
# Val Acc:   82.53%
#
# Fold 1 - Epoch 88/120
# ------------------------------------------------------------
# Train Loss: 0.0838
# Val Acc:   81.51%
#
# Fold 1 - Epoch 89/120
# ------------------------------------------------------------
# Train Loss: 0.0578
# Val Acc:   77.74%
#
# Fold 1 - Epoch 90/120
# ------------------------------------------------------------
# Train Loss: 0.0488
# Val Acc:   82.53%
#
# Fold 1 - Epoch 91/120
# ------------------------------------------------------------
# Train Loss: 0.0414
# Val Acc:   80.48%
#
# Fold 1 - Epoch 92/120
# ------------------------------------------------------------
# Train Loss: 0.0431
# Val Acc:   80.82%
#
# Fold 1 - Epoch 93/120
# ------------------------------------------------------------
# Train Loss: 0.0522
# Val Acc:   81.16%
#
# Fold 1 - Epoch 94/120
# ------------------------------------------------------------
# Train Loss: 0.0449
# Val Acc:   82.53%
#
# Fold 1 - Epoch 95/120
# ------------------------------------------------------------
# Train Loss: 0.0412
# Val Acc:   81.85%
#
# Fold 1 - Epoch 96/120
# ------------------------------------------------------------
# Train Loss: 0.0461
# Val Acc:   82.19%
#
# Fold 1 - Epoch 97/120
# ------------------------------------------------------------
# Train Loss: 0.0521
# Val Acc:   81.51%
#
# Fold 1 - Epoch 98/120
# ------------------------------------------------------------
# Train Loss: 0.0498
# Val Acc:   81.85%
#
# Fold 1 - Epoch 99/120
# ------------------------------------------------------------
# Train Loss: 0.0437
# Val Acc:   83.22%
#
# Fold 1 - Epoch 100/120
# ------------------------------------------------------------
# Train Loss: 0.0348
# Val Acc:   82.19%
#
# Fold 1 - Epoch 101/120
# ------------------------------------------------------------
# Train Loss: 0.0346
# Val Acc:   82.53%
#
# Fold 1 - Epoch 102/120
# ------------------------------------------------------------
# Train Loss: 0.0788
# Val Acc:   78.42%
#
# Fold 1 - Epoch 103/120
# ------------------------------------------------------------
# Train Loss: 0.0887
# Val Acc:   81.16%
#
# Fold 1 - Epoch 104/120
# ------------------------------------------------------------
# Train Loss: 0.0469
# Val Acc:   81.85%
#
# Fold 1 - Epoch 105/120
# ------------------------------------------------------------
# Train Loss: 0.0420
# Val Acc:   82.19%
#
# Fold 1 - Epoch 106/120
# ------------------------------------------------------------
# Train Loss: 0.0393
# Val Acc:   81.16%
#
# Fold 1 - Epoch 107/120
# ------------------------------------------------------------
# Train Loss: 0.0353
# Val Acc:   81.16%
#
# Fold 1 - Epoch 108/120
# ------------------------------------------------------------
# Train Loss: 0.0331
# Val Acc:   81.51%
#
# Fold 1 - Epoch 109/120
# ------------------------------------------------------------
# Train Loss: 0.0364
# Val Acc:   82.19%
#
# Fold 1 - Epoch 110/120
# ------------------------------------------------------------
# Train Loss: 0.0427
# Val Acc:   82.19%
#
# Fold 1 - Epoch 111/120
# ------------------------------------------------------------
# Train Loss: 0.0392
# Val Acc:   81.51%
#
# Fold 1 - Epoch 112/120
# ------------------------------------------------------------
# Train Loss: 0.0312
# Val Acc:   82.19%
#
# Fold 1 - Epoch 113/120
# ------------------------------------------------------------
# Train Loss: 0.0362
# Val Acc:   81.51%
#
# Fold 1 - Epoch 114/120
# ------------------------------------------------------------
# Train Loss: 0.0382
# Val Acc:   82.88%
#
# Fold 1 - Epoch 115/120
# ------------------------------------------------------------
# Train Loss: 0.0450
# Val Acc:   80.82%
#
# Fold 1 - Epoch 116/120
# ------------------------------------------------------------
# Train Loss: 0.0336
# Val Acc:   82.88%
#
# Fold 1 - Epoch 117/120
# ------------------------------------------------------------
# Train Loss: 0.0363
# Val Acc:   83.22%
#
# Fold 1 - Epoch 118/120
# ------------------------------------------------------------
# Train Loss: 0.0315
# Val Acc:   81.16%
#
# Fold 1 - Epoch 119/120
# ------------------------------------------------------------
# Train Loss: 0.0396
# Val Acc:   82.53%
#
# Fold 1 - Epoch 120/120
# ------------------------------------------------------------
# Train Loss: 0.0370
# Val Acc:   81.51%
#
#
# Test Set Evaluation Results (Fold 1):
#   • Accuracy:  81.51%
#   • Precision: 81.89%
#   • Recall:    77.92%
#   • F1-Score:  78.67%
#   • MAE:       3.123
#   • MSE:       5.541
#
# Fold 1 Summary:
#   • Test Accuracy: 81.51%
#   • Test F1-Score: 78.67%
#
#
#
# cross_val_index: 2
#
# Fold 2 - Epoch 10/120
# ------------------------------------------------------------
# Train Loss: 0.3260
# Val Acc:   79.79%
#
# Fold 2 - Epoch 11/120
# ------------------------------------------------------------
# Train Loss: 0.3103
# Val Acc:   77.40%
#
# Fold 2 - Epoch 12/120
# ------------------------------------------------------------
# Train Loss: 0.2935
# Val Acc:   79.45%
#
# Fold 2 - Epoch 13/120
# ------------------------------------------------------------
# Train Loss: 0.2936
# Val Acc:   75.68%
#
# Fold 2 - Epoch 14/120
# ------------------------------------------------------------
# Train Loss: 0.2612
# Val Acc:   79.11%
#
# Fold 2 - Epoch 15/120
# ------------------------------------------------------------
# Train Loss: 0.2443
# Val Acc:   77.05%
#
# Fold 2 - Epoch 16/120
# ------------------------------------------------------------
# Train Loss: 0.2840
# Val Acc:   80.14%
#
# Fold 2 - Epoch 17/120
# ------------------------------------------------------------
# Train Loss: 0.2498
# Val Acc:   79.45%
#
# Fold 2 - Epoch 18/120
# ------------------------------------------------------------
# Train Loss: 0.2315
# Val Acc:   77.05%
#
# Fold 2 - Epoch 19/120
# ------------------------------------------------------------
# Train Loss: 0.2637
# Val Acc:   79.11%
#
# Fold 2 - Epoch 20/120
# ------------------------------------------------------------
# Train Loss: 0.2409
# Val Acc:   79.79%
#
# Fold 2 - Epoch 21/120
# ------------------------------------------------------------
# Train Loss: 0.2248
# Val Acc:   61.99%
#
# Fold 2 - Epoch 22/120
# ------------------------------------------------------------
# Train Loss: 0.2781
# Val Acc:   70.89%
#
# Fold 2 - Epoch 23/120
# ------------------------------------------------------------
# Train Loss: 0.2242
# Val Acc:   76.71%
#
# Fold 2 - Epoch 24/120
# ------------------------------------------------------------
# Train Loss: 0.2110
# Val Acc:   75.34%
#
# Fold 2 - Epoch 25/120
# ------------------------------------------------------------
# Train Loss: 0.2156
# Val Acc:   79.45%
#
# Fold 2 - Epoch 26/120
# ------------------------------------------------------------
# Train Loss: 0.1874
# Val Acc:   76.37%
#
# Fold 2 - Epoch 27/120
# ------------------------------------------------------------
# Train Loss: 0.2004
# Val Acc:   77.05%
#
# Fold 2 - Epoch 28/120
# ------------------------------------------------------------
# Train Loss: 0.1853
# Val Acc:   80.48%
#
# Fold 2 - Epoch 29/120
# ------------------------------------------------------------
# Train Loss: 0.1677
# Val Acc:   76.71%
#
# Fold 2 - Epoch 30/120
# ------------------------------------------------------------
# Train Loss: 0.2552
# Val Acc:   75.68%
#
# Fold 2 - Epoch 31/120
# ------------------------------------------------------------
# Train Loss: 0.1852
# Val Acc:   79.11%
#
# Fold 2 - Epoch 32/120
# ------------------------------------------------------------
# Train Loss: 0.1694
# Val Acc:   81.85%
#
# Fold 2 - Epoch 33/120
# ------------------------------------------------------------
# Train Loss: 0.1711
# Val Acc:   81.51%
#
# Fold 2 - Epoch 34/120
# ------------------------------------------------------------
# Train Loss: 0.1615
# Val Acc:   76.37%
#
# Fold 2 - Epoch 35/120
# ------------------------------------------------------------
# Train Loss: 0.1534
# Val Acc:   77.05%
#
# Fold 2 - Epoch 36/120
# ------------------------------------------------------------
# Train Loss: 0.1477
# Val Acc:   81.51%
#
# Fold 2 - Epoch 37/120
# ------------------------------------------------------------
# Train Loss: 0.1374
# Val Acc:   80.14%
#
# Fold 2 - Epoch 38/120
# ------------------------------------------------------------
# Train Loss: 0.1438
# Val Acc:   79.11%
#
# Fold 2 - Epoch 39/120
# ------------------------------------------------------------
# Train Loss: 0.1265
# Val Acc:   77.05%
#
# Fold 2 - Epoch 40/120
# ------------------------------------------------------------
# Train Loss: 0.1397
# Val Acc:   80.14%
#
# Fold 2 - Epoch 41/120
# ------------------------------------------------------------
# Train Loss: 0.1969
# Val Acc:   80.14%
#
# Fold 2 - Epoch 42/120
# ------------------------------------------------------------
# Train Loss: 0.1698
# Val Acc:   78.42%
#
# Fold 2 - Epoch 43/120
# ------------------------------------------------------------
# Train Loss: 0.1414
# Val Acc:   79.11%
#
# Fold 2 - Epoch 44/120
# ------------------------------------------------------------
# Train Loss: 0.1342
# Val Acc:   79.79%
#
# Fold 2 - Epoch 45/120
# ------------------------------------------------------------
# Train Loss: 0.1127
# Val Acc:   80.48%
#
# Fold 2 - Epoch 46/120
# ------------------------------------------------------------
# Train Loss: 0.1065
# Val Acc:   82.88%
#
# Fold 2 - Epoch 47/120
# ------------------------------------------------------------
# Train Loss: 0.1222
# Val Acc:   77.74%
#
# Fold 2 - Epoch 48/120
# ------------------------------------------------------------
# Train Loss: 0.1104
# Val Acc:   79.79%
#
# Fold 2 - Epoch 49/120
# ------------------------------------------------------------
# Train Loss: 0.1029
# Val Acc:   79.79%
#
# Fold 2 - Epoch 50/120
# ------------------------------------------------------------
# Train Loss: 0.1040
# Val Acc:   76.71%
#
# Fold 2 - Epoch 51/120
# ------------------------------------------------------------
# Train Loss: 0.1168
# Val Acc:   79.79%
#
# Fold 2 - Epoch 52/120
# ------------------------------------------------------------
# Train Loss: 0.1290
# Val Acc:   80.48%
#
# Fold 2 - Epoch 53/120
# ------------------------------------------------------------
# Train Loss: 0.1093
# Val Acc:   79.79%
#
# Fold 2 - Epoch 54/120
# ------------------------------------------------------------
# Train Loss: 0.1108
# Val Acc:   78.77%
#
# Fold 2 - Epoch 55/120
# ------------------------------------------------------------
# Train Loss: 0.0906
# Val Acc:   82.53%
#
# Fold 2 - Epoch 56/120
# ------------------------------------------------------------
# Train Loss: 0.1459
# Val Acc:   77.40%
#
# Fold 2 - Epoch 57/120
# ------------------------------------------------------------
# Train Loss: 0.1198
# Val Acc:   79.45%
#
# Fold 2 - Epoch 58/120
# ------------------------------------------------------------
# Train Loss: 0.0900
# Val Acc:   75.68%
#
# Fold 2 - Epoch 59/120
# ------------------------------------------------------------
# Train Loss: 0.0877
# Val Acc:   83.90%
#
# Fold 2 - Epoch 60/120
# ------------------------------------------------------------
# Train Loss: 0.1045
# Val Acc:   79.45%
#
# Fold 2 - Epoch 61/120
# ------------------------------------------------------------
# Train Loss: 0.1075
# Val Acc:   79.79%
#
# Fold 2 - Epoch 62/120
# ------------------------------------------------------------
# Train Loss: 0.0994
# Val Acc:   83.90%
#
# Fold 2 - Epoch 63/120
# ------------------------------------------------------------
# Train Loss: 0.0903
# Val Acc:   82.53%
#
# Fold 2 - Epoch 64/120
# ------------------------------------------------------------
# Train Loss: 0.0804
# Val Acc:   80.14%
#
# Fold 2 - Epoch 65/120
# ------------------------------------------------------------
# Train Loss: 0.0803
# Val Acc:   80.48%
#
# Fold 2 - Epoch 66/120
# ------------------------------------------------------------
# Train Loss: 0.0857
# Val Acc:   77.05%
#
# Fold 2 - Epoch 67/120
# ------------------------------------------------------------
# Train Loss: 0.0892
# Val Acc:   79.45%
#
# Fold 2 - Epoch 68/120
# ------------------------------------------------------------
# Train Loss: 0.0704
# Val Acc:   79.45%
#
# Fold 2 - Epoch 69/120
# ------------------------------------------------------------
# Train Loss: 0.0722
# Val Acc:   76.03%
#
# Fold 2 - Epoch 70/120
# ------------------------------------------------------------
# Train Loss: 0.0757
# Val Acc:   80.48%
#
# Fold 2 - Epoch 71/120
# ------------------------------------------------------------
# Train Loss: 0.0721
# Val Acc:   80.48%
#
# Fold 2 - Epoch 72/120
# ------------------------------------------------------------
# Train Loss: 0.0854
# Val Acc:   79.11%
#
# Fold 2 - Epoch 73/120
# ------------------------------------------------------------
# Train Loss: 0.0938
# Val Acc:   75.00%
#
# Fold 2 - Epoch 74/120
# ------------------------------------------------------------
# Train Loss: 0.0745
# Val Acc:   81.16%
#
# Fold 2 - Epoch 75/120
# ------------------------------------------------------------
# Train Loss: 0.0693
# Val Acc:   79.45%
#
# Fold 2 - Epoch 76/120
# ------------------------------------------------------------
# Train Loss: 0.0688
# Val Acc:   79.45%
#
# Fold 2 - Epoch 77/120
# ------------------------------------------------------------
# Train Loss: 0.0724
# Val Acc:   81.85%
#
# Fold 2 - Epoch 78/120
# ------------------------------------------------------------
# Train Loss: 0.0601
# Val Acc:   78.77%
#
# Fold 2 - Epoch 79/120
# ------------------------------------------------------------
# Train Loss: 0.0689
# Val Acc:   81.51%
#
# Fold 2 - Epoch 80/120
# ------------------------------------------------------------
# Train Loss: 0.0616
# Val Acc:   80.14%
#
# Fold 2 - Epoch 81/120
# ------------------------------------------------------------
# Train Loss: 0.0583
# Val Acc:   81.16%
#
# Fold 2 - Epoch 82/120
# ------------------------------------------------------------
# Train Loss: 0.0752
# Val Acc:   80.14%
#
# Fold 2 - Epoch 83/120
# ------------------------------------------------------------
# Train Loss: 0.0820
# Val Acc:   80.14%
#
# Fold 2 - Epoch 84/120
# ------------------------------------------------------------
# Train Loss: 0.0579
# Val Acc:   81.51%
#
# Fold 2 - Epoch 85/120
# ------------------------------------------------------------
# Train Loss: 0.0639
# Val Acc:   79.79%
#
# Fold 2 - Epoch 86/120
# ------------------------------------------------------------
# Train Loss: 0.0611
# Val Acc:   81.16%
#
# Fold 2 - Epoch 87/120
# ------------------------------------------------------------
# Train Loss: 0.0603
# Val Acc:   80.14%
#
# Fold 2 - Epoch 88/120
# ------------------------------------------------------------
# Train Loss: 0.0626
# Val Acc:   77.40%
#
# Fold 2 - Epoch 89/120
# ------------------------------------------------------------
# Train Loss: 0.0523
# Val Acc:   79.45%
#
# Fold 2 - Epoch 90/120
# ------------------------------------------------------------
# Train Loss: 0.0543
# Val Acc:   81.85%
#
# Fold 2 - Epoch 91/120
# ------------------------------------------------------------
# Train Loss: 0.0522
# Val Acc:   82.53%
#
# Fold 2 - Epoch 92/120
# ------------------------------------------------------------
# Train Loss: 0.0481
# Val Acc:   82.19%
#
# Fold 2 - Epoch 93/120
# ------------------------------------------------------------
# Train Loss: 0.0551
# Val Acc:   83.22%
#
# Fold 2 - Epoch 94/120
# ------------------------------------------------------------
# Train Loss: 0.0594
# Val Acc:   79.11%
#
# Fold 2 - Epoch 95/120
# ------------------------------------------------------------
# Train Loss: 0.0736
# Val Acc:   80.14%
#
# Fold 2 - Epoch 96/120
# ------------------------------------------------------------
# Train Loss: 0.0594
# Val Acc:   79.11%
#
# Fold 2 - Epoch 97/120
# ------------------------------------------------------------
# Train Loss: 0.0438
# Val Acc:   80.48%
#
# Fold 2 - Epoch 98/120
# ------------------------------------------------------------
# Train Loss: 0.0930
# Val Acc:   77.74%
#
# Fold 2 - Epoch 99/120
# ------------------------------------------------------------
# Train Loss: 0.0613
# Val Acc:   79.79%
#
# Fold 2 - Epoch 100/120
# ------------------------------------------------------------
# Train Loss: 0.0550
# Val Acc:   82.88%
#
# Fold 2 - Epoch 101/120
# ------------------------------------------------------------
# Train Loss: 0.0552
# Val Acc:   80.82%
#
# Fold 2 - Epoch 102/120
# ------------------------------------------------------------
# Train Loss: 0.0415
# Val Acc:   81.16%
#
# Fold 2 - Epoch 103/120
# ------------------------------------------------------------
# Train Loss: 0.0405
# Val Acc:   78.77%
#
# Fold 2 - Epoch 104/120
# ------------------------------------------------------------
# Train Loss: 0.0365
# Val Acc:   79.79%
#
# Fold 2 - Epoch 105/120
# ------------------------------------------------------------
# Train Loss: 0.0425
# Val Acc:   83.22%
#
# Fold 2 - Epoch 106/120
# ------------------------------------------------------------
# Train Loss: 0.0458
# Val Acc:   80.82%
#
# Fold 2 - Epoch 107/120
# ------------------------------------------------------------
# Train Loss: 0.0471
# Val Acc:   78.08%
#
# Fold 2 - Epoch 108/120
# ------------------------------------------------------------
# Train Loss: 0.0423
# Val Acc:   77.74%
#
# Fold 2 - Epoch 109/120
# ------------------------------------------------------------
# Train Loss: 0.0399
# Val Acc:   82.19%
#
# Fold 2 - Epoch 110/120
# ------------------------------------------------------------
# Train Loss: 0.0385
# Val Acc:   80.82%
#
# Fold 2 - Epoch 111/120
# ------------------------------------------------------------
# Train Loss: 0.0372
# Val Acc:   80.14%
#
# Fold 2 - Epoch 112/120
# ------------------------------------------------------------
# Train Loss: 0.0371
# Val Acc:   79.45%
#
# Fold 2 - Epoch 113/120
# ------------------------------------------------------------
# Train Loss: 0.0403
# Val Acc:   80.48%
#
# Fold 2 - Epoch 114/120
# ------------------------------------------------------------
# Train Loss: 0.0372
# Val Acc:   80.82%
#
# Fold 2 - Epoch 115/120
# ------------------------------------------------------------
# Train Loss: 0.0342
# Val Acc:   80.82%
#
# Fold 2 - Epoch 116/120
# ------------------------------------------------------------
# Train Loss: 0.0312
# Val Acc:   82.53%
#
# Fold 2 - Epoch 117/120
# ------------------------------------------------------------
# Train Loss: 0.0311
# Val Acc:   79.79%
#
# Fold 2 - Epoch 118/120
# ------------------------------------------------------------
# Train Loss: 0.0316
# Val Acc:   82.19%
#
# Fold 2 - Epoch 119/120
# ------------------------------------------------------------
# Train Loss: 0.0375
# Val Acc:   80.48%
#
# Fold 2 - Epoch 120/120
# ------------------------------------------------------------
# Train Loss: 0.0372
# Val Acc:   81.85%
#
#
# Test Set Evaluation Results (Fold 2):
#   • Accuracy:  81.85%
#   • Precision: 81.32%
#   • Recall:    78.54%
#   • F1-Score:  79.82%
#   • MAE:       3.092
#   • MSE:       5.429
#
# Fold 2 Summary:
#   • Test Accuracy: 81.85%
#   • Test F1-Score: 79.82%
#
#
#
# cross_val_index: 3
#
# Fold 3 - Epoch 10/120
# ------------------------------------------------------------
# Train Loss: 0.2926
# Val Acc:   76.71%
#
# Fold 3 - Epoch 11/120
# ------------------------------------------------------------
# Train Loss: 0.3437
# Val Acc:   80.82%
#
# Fold 3 - Epoch 12/120
# ------------------------------------------------------------
# Train Loss: 0.2993
# Val Acc:   74.66%
#
# Fold 3 - Epoch 13/120
# ------------------------------------------------------------
# Train Loss: 0.2794
# Val Acc:   68.49%
#
# Fold 3 - Epoch 14/120
# ------------------------------------------------------------
# Train Loss: 0.2654
# Val Acc:   77.40%
#
# Fold 3 - Epoch 15/120
# ------------------------------------------------------------
# Train Loss: 0.2858
# Val Acc:   76.37%
#
# Fold 3 - Epoch 16/120
# ------------------------------------------------------------
# Train Loss: 0.2437
# Val Acc:   78.42%
#
# Fold 3 - Epoch 17/120
# ------------------------------------------------------------
# Train Loss: 0.2681
# Val Acc:   71.92%
#
# Fold 3 - Epoch 18/120
# ------------------------------------------------------------
# Train Loss: 0.2628
# Val Acc:   80.48%
#
# Fold 3 - Epoch 19/120
# ------------------------------------------------------------
# Train Loss: 0.2294
# Val Acc:   79.11%
#
# Fold 3 - Epoch 20/120
# ------------------------------------------------------------
# Train Loss: 0.2463
# Val Acc:   79.79%
#
# Fold 3 - Epoch 21/120
# ------------------------------------------------------------
# Train Loss: 0.2075
# Val Acc:   76.03%
#
# Fold 3 - Epoch 22/120
# ------------------------------------------------------------
# Train Loss: 0.1955
# Val Acc:   82.88%
#
# Fold 3 - Epoch 23/120
# ------------------------------------------------------------
# Train Loss: 0.1848
# Val Acc:   80.82%
#
# Fold 3 - Epoch 24/120
# ------------------------------------------------------------
# Train Loss: 0.2036
# Val Acc:   78.77%
#
# Fold 3 - Epoch 25/120
# ------------------------------------------------------------
# Train Loss: 0.1936
# Val Acc:   66.44%
#
# Fold 3 - Epoch 26/120
# ------------------------------------------------------------
# Train Loss: 0.2435
# Val Acc:   79.79%
#
# Fold 3 - Epoch 27/120
# ------------------------------------------------------------
# Train Loss: 0.1809
# Val Acc:   80.14%
#
# Fold 3 - Epoch 28/120
# ------------------------------------------------------------
# Train Loss: 0.2161
# Val Acc:   77.05%
#
# Fold 3 - Epoch 29/120
# ------------------------------------------------------------
# Train Loss: 0.1899
# Val Acc:   78.77%
#
# Fold 3 - Epoch 30/120
# ------------------------------------------------------------
# Train Loss: 0.1868
# Val Acc:   73.63%
#
# Fold 3 - Epoch 31/120
# ------------------------------------------------------------
# Train Loss: 0.1792
# Val Acc:   82.53%
#
# Fold 3 - Epoch 32/120
# ------------------------------------------------------------
# Train Loss: 0.1431
# Val Acc:   78.77%
#
# Fold 3 - Epoch 33/120
# ------------------------------------------------------------
# Train Loss: 0.1662
# Val Acc:   75.00%
#
# Fold 3 - Epoch 34/120
# ------------------------------------------------------------
# Train Loss: 0.1957
# Val Acc:   72.95%
#
# Fold 3 - Epoch 35/120
# ------------------------------------------------------------
# Train Loss: 0.1813
# Val Acc:   79.45%
#
# Fold 3 - Epoch 36/120
# ------------------------------------------------------------
# Train Loss: 0.1557
# Val Acc:   79.79%
#
# Fold 3 - Epoch 37/120
# ------------------------------------------------------------
# Train Loss: 0.1402
# Val Acc:   81.16%
#
# Fold 3 - Epoch 38/120
# ------------------------------------------------------------
# Train Loss: 0.1297
# Val Acc:   81.16%
#
# Fold 3 - Epoch 39/120
# ------------------------------------------------------------
# Train Loss: 0.1306
# Val Acc:   78.77%
#
# Fold 3 - Epoch 40/120
# ------------------------------------------------------------
# Train Loss: 0.1424
# Val Acc:   78.77%
#
# Fold 3 - Epoch 41/120
# ------------------------------------------------------------
# Train Loss: 0.1579
# Val Acc:   82.88%
#
# Fold 3 - Epoch 42/120
# ------------------------------------------------------------
# Train Loss: 0.1634
# Val Acc:   81.51%
#
# Fold 3 - Epoch 43/120
# ------------------------------------------------------------
# Train Loss: 0.1527
# Val Acc:   82.19%
#
# Fold 3 - Epoch 44/120
# ------------------------------------------------------------
# Train Loss: 0.1164
# Val Acc:   80.14%
#
# Fold 3 - Epoch 45/120
# ------------------------------------------------------------
# Train Loss: 0.1211
# Val Acc:   75.00%
#
# Fold 3 - Epoch 46/120
# ------------------------------------------------------------
# Train Loss: 0.1239
# Val Acc:   80.48%
#
# Fold 3 - Epoch 47/120
# ------------------------------------------------------------
# Train Loss: 0.1123
# Val Acc:   81.51%
#
# Fold 3 - Epoch 48/120
# ------------------------------------------------------------
# Train Loss: 0.1340
# Val Acc:   76.03%
#
# Fold 3 - Epoch 49/120
# ------------------------------------------------------------
# Train Loss: 0.1146
# Val Acc:   82.19%
#
# Fold 3 - Epoch 50/120
# ------------------------------------------------------------
# Train Loss: 0.1099
# Val Acc:   79.79%
#
# Fold 3 - Epoch 51/120
# ------------------------------------------------------------
# Train Loss: 0.1043
# Val Acc:   78.77%
#
# Fold 3 - Epoch 52/120
# ------------------------------------------------------------
# Train Loss: 0.0943
# Val Acc:   82.53%
#
# Fold 3 - Epoch 53/120
# ------------------------------------------------------------
# Train Loss: 0.1146
# Val Acc:   81.16%
#
# Fold 3 - Epoch 54/120
# ------------------------------------------------------------
# Train Loss: 0.1156
# Val Acc:   80.14%
#
# Fold 3 - Epoch 55/120
# ------------------------------------------------------------
# Train Loss: 0.0912
# Val Acc:   78.42%
#
# Fold 3 - Epoch 56/120
# ------------------------------------------------------------
# Train Loss: 0.1214
# Val Acc:   82.19%
#
# Fold 3 - Epoch 57/120
# ------------------------------------------------------------
# Train Loss: 0.1206
# Val Acc:   78.77%
#
# Fold 3 - Epoch 58/120
# ------------------------------------------------------------
# Train Loss: 0.1289
# Val Acc:   77.05%
#
# Fold 3 - Epoch 59/120
# ------------------------------------------------------------
# Train Loss: 0.1061
# Val Acc:   79.79%
#
# Fold 3 - Epoch 60/120
# ------------------------------------------------------------
# Train Loss: 0.1113
# Val Acc:   79.11%
#
# Fold 3 - Epoch 61/120
# ------------------------------------------------------------
# Train Loss: 0.0970
# Val Acc:   82.19%
#
# Fold 3 - Epoch 62/120
# ------------------------------------------------------------
# Train Loss: 0.0843
# Val Acc:   82.19%
#
# Fold 3 - Epoch 63/120
# ------------------------------------------------------------
# Train Loss: 0.0802
# Val Acc:   80.82%
#
# Fold 3 - Epoch 64/120
# ------------------------------------------------------------
# Train Loss: 0.0840
# Val Acc:   82.53%
#
# Fold 3 - Epoch 65/120
# ------------------------------------------------------------
# Train Loss: 0.0798
# Val Acc:   80.48%
#
# Fold 3 - Epoch 66/120
# ...
# ------------------------------------------------------------
# Train Loss: 0.0330
# Val Acc:   80.82%
#
# Fold 3 - Epoch 112/120
# ------------------------------------------------------------
# Train Loss: 0.0422
# Val Acc:   80.82%
#
# Fold 3 - Epoch 113/120
# ------------------------------------------------------------
# Train Loss: 0.0365
# Val Acc:   80.14%
#
# Fold 3 - Epoch 114/120
# ------------------------------------------------------------
# Train Loss: 0.0389
# Val Acc:   81.85%
#
# Fold 3 - Epoch 115/120
# ------------------------------------------------------------
# Train Loss: 0.0375
# Val Acc:   81.51%
#
# Fold 3 - Epoch 116/120
# ------------------------------------------------------------
# Train Loss: 0.0327
# Val Acc:   83.90%
#
# Fold 3 - Epoch 117/120
# ------------------------------------------------------------
# Train Loss: 0.0331
# Val Acc:   82.88%
#
# Fold 3 - Epoch 118/120
# ------------------------------------------------------------
# Train Loss: 0.0309
# Val Acc:   81.16%
#
# Fold 3 - Epoch 119/120
# ------------------------------------------------------------
# Train Loss: 0.0343
# Val Acc:   79.45%
#
# Fold 3 - Epoch 120/120
# ------------------------------------------------------------
# Train Loss: 0.0355
# Val Acc:   83.56%
#
#
# Test Set Evaluation Results (Fold 3):
#   • Accuracy:  83.56%
#   • Precision: 81.72%
#   • Recall:    77.46%
#   • F1-Score:  79.25%
#   • MAE:       3.428
#   • MSE:       6.233
#
# Fold 3 Summary:
#   • Test Accuracy: 83.56%
#   • Test F1-Score: 79.25%
#
#
#
# cross_val_index: 4
#
# Fold 4 - Epoch 10/120
# ------------------------------------------------------------
# Train Loss: 0.3842
# Val Acc:   74.66%
#
# Fold 4 - Epoch 11/120
# ------------------------------------------------------------
# Train Loss: 0.3073
# Val Acc:   80.48%
#
# Fold 4 - Epoch 12/120
# ------------------------------------------------------------
# Train Loss: 0.3355
# Val Acc:   77.74%
#
# Fold 4 - Epoch 13/120
# ------------------------------------------------------------
# Train Loss: 0.3259
# Val Acc:   74.66%
#
# Fold 4 - Epoch 14/120
# ------------------------------------------------------------
# Train Loss: 0.2606
# Val Acc:   65.41%
#
# Fold 4 - Epoch 15/120
# ------------------------------------------------------------
# Train Loss: 0.3182
# Val Acc:   69.52%
#
# Fold 4 - Epoch 16/120
# ------------------------------------------------------------
# Train Loss: 0.2544
# Val Acc:   77.05%
#
# Fold 4 - Epoch 17/120
# ------------------------------------------------------------
# Train Loss: 0.2737
# Val Acc:   77.74%
#
# Fold 4 - Epoch 18/120
# ------------------------------------------------------------
# Train Loss: 0.2355
# Val Acc:   78.08%
#
# Fold 4 - Epoch 19/120
# ------------------------------------------------------------
# Train Loss: 0.2390
# Val Acc:   67.47%
#
# Fold 4 - Epoch 20/120
# ------------------------------------------------------------
# Train Loss: 0.2164
# Val Acc:   71.23%
#
# Fold 4 - Epoch 21/120
# ------------------------------------------------------------
# Train Loss: 0.2437
# Val Acc:   74.32%
#
# Fold 4 - Epoch 22/120
# ------------------------------------------------------------
# Train Loss: 0.2156
# Val Acc:   74.66%
#
# Fold 4 - Epoch 23/120
# ------------------------------------------------------------
# Train Loss: 0.2182
# Val Acc:   79.79%
#
# Fold 4 - Epoch 24/120
# ------------------------------------------------------------
# Train Loss: 0.1928
# Val Acc:   72.60%
#
# Fold 4 - Epoch 25/120
# ------------------------------------------------------------
# Train Loss: 0.1871
# Val Acc:   77.40%
#
# Fold 4 - Epoch 26/120
# ------------------------------------------------------------
# Train Loss: 0.2213
# Val Acc:   76.71%
#
# Fold 4 - Epoch 27/120
# ------------------------------------------------------------
# Train Loss: 0.1885
# Val Acc:   70.55%
#
# Fold 4 - Epoch 28/120
# ------------------------------------------------------------
# Train Loss: 0.1868
# Val Acc:   77.05%
#
# Fold 4 - Epoch 29/120
# ------------------------------------------------------------
# Train Loss: 0.1788
# Val Acc:   79.45%
#
# Fold 4 - Epoch 30/120
# ------------------------------------------------------------
# Train Loss: 0.2088
# Val Acc:   77.74%
#
# Fold 4 - Epoch 31/120
# ------------------------------------------------------------
# Train Loss: 0.1716
# Val Acc:   81.16%
#
# Fold 4 - Epoch 32/120
# ------------------------------------------------------------
# Train Loss: 0.1707
# Val Acc:   80.48%
#
# Fold 4 - Epoch 33/120
# ------------------------------------------------------------
# Train Loss: 0.1881
# Val Acc:   78.08%
#
# Fold 4 - Epoch 34/120
# ------------------------------------------------------------
# Train Loss: 0.1455
# Val Acc:   80.14%
#
# Fold 4 - Epoch 35/120
# ------------------------------------------------------------
# Train Loss: 0.1362
# Val Acc:   78.08%
#
# Fold 4 - Epoch 36/120
# ------------------------------------------------------------
# Train Loss: 0.1646
# Val Acc:   82.53%
#
# Fold 4 - Epoch 37/120
# ------------------------------------------------------------
# Train Loss: 0.1698
# Val Acc:   79.45%
#
# Fold 4 - Epoch 38/120
# ------------------------------------------------------------
# Train Loss: 0.1418
# Val Acc:   79.79%
#
# Fold 4 - Epoch 39/120
# ------------------------------------------------------------
# Train Loss: 0.1437
# Val Acc:   76.03%
#
# Fold 4 - Epoch 40/120
# ------------------------------------------------------------
# Train Loss: 0.1401
# Val Acc:   77.74%
#
# Fold 4 - Epoch 41/120
# ------------------------------------------------------------
# Train Loss: 0.1478
# Val Acc:   75.34%
#
# Fold 4 - Epoch 42/120
# ------------------------------------------------------------
# Train Loss: 0.1304
# Val Acc:   77.05%
#
# Fold 4 - Epoch 43/120
# ------------------------------------------------------------
# Train Loss: 0.1251
# Val Acc:   75.00%
#
# Fold 4 - Epoch 44/120
# ------------------------------------------------------------
# Train Loss: 0.1238
# Val Acc:   80.82%
#
# Fold 4 - Epoch 45/120
# ------------------------------------------------------------
# Train Loss: 0.1141
# Val Acc:   80.14%
#
# Fold 4 - Epoch 46/120
# ------------------------------------------------------------
# Train Loss: 0.1084
# Val Acc:   79.45%
#
# Fold 4 - Epoch 47/120
# ------------------------------------------------------------
# Train Loss: 0.1600
# Val Acc:   68.49%
#
# Fold 4 - Epoch 48/120
# ------------------------------------------------------------
# Train Loss: 0.1752
# Val Acc:   79.11%
#
# Fold 4 - Epoch 49/120
# ------------------------------------------------------------
# Train Loss: 0.1259
# Val Acc:   79.79%
#
# Fold 4 - Epoch 50/120
# ------------------------------------------------------------
# Train Loss: 0.1189
# Val Acc:   80.14%
#
# Fold 4 - Epoch 51/120
# ------------------------------------------------------------
# Train Loss: 0.1085
# Val Acc:   78.42%
#
# Fold 4 - Epoch 52/120
# ------------------------------------------------------------
# Train Loss: 0.0980
# Val Acc:   78.77%
#
# Fold 4 - Epoch 53/120
# ------------------------------------------------------------
# Train Loss: 0.1057
# Val Acc:   74.32%
#
# Fold 4 - Epoch 54/120
# ------------------------------------------------------------
# Train Loss: 0.1350
# Val Acc:   80.82%
#
# Fold 4 - Epoch 55/120
# ------------------------------------------------------------
# Train Loss: 0.1125
# Val Acc:   75.00%
#
# Fold 4 - Epoch 56/120
# ------------------------------------------------------------
# Train Loss: 0.1407
# Val Acc:   80.48%
#
# Fold 4 - Epoch 57/120
# ------------------------------------------------------------
# Train Loss: 0.0976
# Val Acc:   80.14%
#
# Fold 4 - Epoch 58/120
# ------------------------------------------------------------
# Train Loss: 0.0863
# Val Acc:   77.40%
#
# Fold 4 - Epoch 59/120
# ------------------------------------------------------------
# Train Loss: 0.0951
# Val Acc:   79.11%
#
# Fold 4 - Epoch 60/120
# ------------------------------------------------------------
# Train Loss: 0.1222
# Val Acc:   78.42%
#
# Fold 4 - Epoch 61/120
# ------------------------------------------------------------
# Train Loss: 0.0814
# Val Acc:   75.00%
#
# Fold 4 - Epoch 62/120
# ------------------------------------------------------------
# Train Loss: 0.0914
# Val Acc:   74.66%
#
# Fold 4 - Epoch 63/120
# ------------------------------------------------------------
# Train Loss: 0.0861
# Val Acc:   77.05%
#
# Fold 4 - Epoch 64/120
# ------------------------------------------------------------
# Train Loss: 0.0760
# Val Acc:   77.05%
#
# Fold 4 - Epoch 65/120
# ------------------------------------------------------------
# Train Loss: 0.0721
# Val Acc:   80.48%
#
# Fold 4 - Epoch 66/120
# ------------------------------------------------------------
# Train Loss: 0.0723
# Val Acc:   80.14%
#
# Fold 4 - Epoch 67/120
# ------------------------------------------------------------
# Train Loss: 0.0730
# Val Acc:   77.40%
#
# Fold 4 - Epoch 68/120
# ------------------------------------------------------------
# Train Loss: 0.1013
# Val Acc:   79.11%
#
# Fold 4 - Epoch 69/120
# ------------------------------------------------------------
# Train Loss: 0.0777
# Val Acc:   80.82%
#
# Fold 4 - Epoch 70/120
# ------------------------------------------------------------
# Train Loss: 0.0658
# Val Acc:   79.11%
#
# Fold 4 - Epoch 71/120
# ------------------------------------------------------------
# Train Loss: 0.0676
# Val Acc:   76.37%
#
# Fold 4 - Epoch 72/120
# ------------------------------------------------------------
# Train Loss: 0.0643
# Val Acc:   79.11%
#
# Fold 4 - Epoch 73/120
# ------------------------------------------------------------
# Train Loss: 0.0653
# Val Acc:   79.45%
#
# Fold 4 - Epoch 74/120
# ------------------------------------------------------------
# Train Loss: 0.0690
# Val Acc:   75.68%
#
# Fold 4 - Epoch 75/120
# ------------------------------------------------------------
# Train Loss: 0.0632
# Val Acc:   82.19%
#
# Fold 4 - Epoch 76/120
# ------------------------------------------------------------
# Train Loss: 0.0563
# Val Acc:   76.71%
#
# Fold 4 - Epoch 77/120
# ------------------------------------------------------------
# Train Loss: 0.0670
# Val Acc:   77.05%
#
# Fold 4 - Epoch 78/120
# ------------------------------------------------------------
# Train Loss: 0.0657
# Val Acc:   80.82%
#
# Fold 4 - Epoch 79/120
# ------------------------------------------------------------
# Train Loss: 0.0733
# Val Acc:   79.11%
#
# Fold 4 - Epoch 80/120
# ------------------------------------------------------------
# Train Loss: 0.0669
# Val Acc:   77.40%
#
# Fold 4 - Epoch 81/120
# ------------------------------------------------------------
# Train Loss: 0.0666
# Val Acc:   78.77%
#
# Fold 4 - Epoch 82/120
# ------------------------------------------------------------
# Train Loss: 0.0518
# Val Acc:   79.11%
#
# Fold 4 - Epoch 83/120
# ------------------------------------------------------------
# Train Loss: 0.0620
# Val Acc:   79.11%
#
# Fold 4 - Epoch 84/120
# ------------------------------------------------------------
# Train Loss: 0.0528
# Val Acc:   77.74%
#
# Fold 4 - Epoch 85/120
# ------------------------------------------------------------
# Train Loss: 0.0531
# Val Acc:   80.14%
#
# Fold 4 - Epoch 86/120
# ------------------------------------------------------------
# Train Loss: 0.0520
# Val Acc:   76.71%
#
# Fold 4 - Epoch 87/120
# ------------------------------------------------------------
# Train Loss: 0.0500
# Val Acc:   80.14%
#
# Fold 4 - Epoch 88/120
# ------------------------------------------------------------
# Train Loss: 0.0539
# Val Acc:   76.37%
#
# Fold 4 - Epoch 89/120
# ------------------------------------------------------------
# Train Loss: 0.0578
# Val Acc:   81.16%
#
# Fold 4 - Epoch 90/120
# ------------------------------------------------------------
# Train Loss: 0.0508
# Val Acc:   82.53%
#
# Fold 4 - Epoch 91/120
# ------------------------------------------------------------
# Train Loss: 0.0455
# Val Acc:   81.51%
#
# Fold 4 - Epoch 92/120
# ------------------------------------------------------------
# Train Loss: 0.0608
# Val Acc:   79.11%
#
# Fold 4 - Epoch 93/120
# ------------------------------------------------------------
# Train Loss: 0.0479
# Val Acc:   78.08%
#
# Fold 4 - Epoch 94/120
# ------------------------------------------------------------
# Train Loss: 0.0461
# Val Acc:   76.71%
#
# Fold 4 - Epoch 95/120
# ------------------------------------------------------------
# Train Loss: 0.0432
# Val Acc:   81.51%
#
# Fold 4 - Epoch 96/120
# ------------------------------------------------------------
# Train Loss: 0.0366
# Val Acc:   79.79%
#
# Fold 4 - Epoch 97/120
# ------------------------------------------------------------
# Train Loss: 0.0437
# Val Acc:   79.45%
#
# Fold 4 - Epoch 98/120
# ------------------------------------------------------------
# Train Loss: 0.0437
# Val Acc:   79.11%
#
# Fold 4 - Epoch 99/120
# ------------------------------------------------------------
# Train Loss: 0.0451
# Val Acc:   76.03%
#
# Fold 4 - Epoch 100/120
# ------------------------------------------------------------
# Train Loss: 0.0449
# Val Acc:   80.48%
#
# Fold 4 - Epoch 101/120
# ------------------------------------------------------------
# Train Loss: 0.0505
# Val Acc:   77.05%
#
# Fold 4 - Epoch 102/120
# ------------------------------------------------------------
# Train Loss: 0.0451
# Val Acc:   77.74%
#
# Fold 4 - Epoch 103/120
# ------------------------------------------------------------
# Train Loss: 0.0331
# Val Acc:   78.77%
#
# Fold 4 - Epoch 104/120
# ------------------------------------------------------------
# Train Loss: 0.0429
# Val Acc:   81.51%
#
# Fold 4 - Epoch 105/120
# ------------------------------------------------------------
# Train Loss: 0.0399
# Val Acc:   78.77%
#
# Fold 4 - Epoch 106/120
# ------------------------------------------------------------
# Train Loss: 0.0374
# Val Acc:   80.14%
#
# Fold 4 - Epoch 107/120
# ------------------------------------------------------------
# Train Loss: 0.0382
# Val Acc:   76.71%
#
# Fold 4 - Epoch 108/120
# ------------------------------------------------------------
# Train Loss: 0.0534
# Val Acc:   77.05%
#
# Fold 4 - Epoch 109/120
# ------------------------------------------------------------
# Train Loss: 0.0412
# Val Acc:   80.82%
#
# Fold 4 - Epoch 110/120
# ------------------------------------------------------------
# Train Loss: 0.0395
# Val Acc:   77.74%
#
# Fold 4 - Epoch 111/120
# ------------------------------------------------------------
# Train Loss: 0.0364
# Val Acc:   79.45%
#
# Fold 4 - Epoch 112/120
# ------------------------------------------------------------
# Train Loss: 0.0373
# Val Acc:   78.42%
#
# Fold 4 - Epoch 113/120
# ------------------------------------------------------------
# Train Loss: 0.0405
# Val Acc:   78.08%
#
# Fold 4 - Epoch 114/120
# ------------------------------------------------------------
# Train Loss: 0.0346
# Val Acc:   78.42%
#
# Fold 4 - Epoch 115/120
# ------------------------------------------------------------
# Train Loss: 0.0312
# Val Acc:   81.51%
#
# Fold 4 - Epoch 116/120
# ------------------------------------------------------------
# Train Loss: 0.0468
# Val Acc:   80.14%
#
# Fold 4 - Epoch 117/120
# ------------------------------------------------------------
# Train Loss: 0.0462
# Val Acc:   79.11%
#
# Fold 4 - Epoch 118/120
# ------------------------------------------------------------
# Train Loss: 0.0550
# Val Acc:   82.19%
#
# Fold 4 - Epoch 119/120
# ------------------------------------------------------------
# Train Loss: 0.0371
# Val Acc:   78.77%
#
# Fold 4 - Epoch 120/120
# ------------------------------------------------------------
# Train Loss: 0.0371
# Val Acc:   78.42%
#
#
# Test Set Evaluation Results (Fold 4):
#   • Accuracy:  78.42%
#   • Precision: 78.13%
#   • Recall:    70.88%
#   • F1-Score:  71.76%
#   • MAE:       3.651
#   • MSE:       7.535
#
# Fold 4 Summary:
#   • Test Accuracy: 78.42%
#   • Test F1-Score: 71.76%
#
#
# ============================================================
# K-FOLD TEST SET EVALUATION RESULTS
# ============================================================
#
#  fold  acc     prec    recall  f1     mae     mse
#     1   81.85   82.22   79.22   80.41   3.188   6.060
#     2   81.51   81.89   77.92   78.67   3.123   5.541
#     3   81.85   81.32   78.54   79.82   3.092   5.429
#     4   83.56   81.72   77.46   79.25   3.428   6.233
#     5   78.42   78.13   70.88   71.76   3.651   7.535
#
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# 📈 Final Test Set Performance :
#   • Mean Accuracy:  81.44% ± 1.67%
#   • Mean Precision: 81.05% ± 1.49%
#   • Mean Recall:    76.80% ± 3.02%
#   • Mean F1-Score:  77.98% ± 3.17%
#   • Mean MAE:       3.297
#   • Mean MSE:       6.160
